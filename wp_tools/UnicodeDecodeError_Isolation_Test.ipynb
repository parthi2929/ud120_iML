# %% [markdown]
# Apparantly, this “sara” is not decoded properly. python unable to read, throwing unicodedecodeerror, charamp unable to decode byte 0x9d at ...
#
# So instead they should be replaced by "sara"

# %% [markdown]
# ![2018-07-09_12h36_55.png](attachment:2018-07-09_12h36_55.png)

# %% [markdown]
# What is this “ that python struggle to decode? Is it not defined in unicode?
